# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeshail641/CodeClauseInternship_Speech_Emotion_Recognition/blob/main/CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
ima=cv2.imread("apple.jpg")

# %%
plt.imshow(ima)

# %%
ima=cv2.cvtColor(ima,cv2.COLOR_BGR2RGB)
plt.imshow(ima)
